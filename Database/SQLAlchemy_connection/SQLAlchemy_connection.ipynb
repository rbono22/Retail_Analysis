# %%
import pandas as pd
import re
from sqlalchemy import create_engine
import psycopg2
from config import db_password
import time

# %%
# read in CSV
retail_df = pd.read_csv('../../Resources/cleaned_datasets/final_cleaned_dataset.csv')
retail_df.head()
# Out:
#    store type    size  dept        date  weekly_sales  temperature  \
# 0      6    A  202505  91.0  2010-06-04      47689.17        79.44
# 1      6    A  202505  91.0  2010-06-11      48320.06        81.81
# 2      6    A  202505  91.0  2010-06-18      48363.68        83.89
# 3      6    A  202505  91.0  2010-06-25      44107.29        84.20
# 4      6    A  202505  91.0  2010-07-02      48001.02        80.34
#
#    fuel_price         cpi  inflation     dspi  unemployment isholiday
# 0       2.705  212.698244   1.640043  11319.4         7.092         f
# 1       2.668  212.983599   1.640043  11319.4         7.092         f
# 2       2.637  212.981384   1.640043  11319.4         7.092         f
# 3       2.653  212.864141   1.640043  11319.4         7.092         f
# 4       2.669  212.746898   1.640043  11347.8         6.973         f

# %%
# Creating connection to PostgreSQL database
# database is named final_project
# final table creation query is available in the "Queries" folder
# db_password can be changed in the config.py file
# port 5433 is used, but this can be changed to match your settings
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5433/final_project"
engine = create_engine(db_string)
retail_df.to_sql(name='retail', con=engine, if_exists='replace')

# %%
# export the data to a SQL table
rows_imported = 0
# get the start_time
start_time = time.time()
for data in pd.read_csv(f'../../Resources/cleaned_datasets/final_cleaned_dataset.csv', chunksize=10000):
    print(f'importing rows {rows_imported} to {rows_imported + len(data)}...', end='')
    data.to_sql(name='retail', con=engine, if_exists='replace')
    rows_imported += len(data)
    # add elapsed time to final print out
    print(f'Done. {time.time() - start_time} total seconds elapsed')
# Out:
# importing rows 0 to 10000...Done. 0.8639371395111084 total seconds elapsed
# importing rows 10000 to 20000...Done. 1.7222909927368164 total seconds elapsed
# importing rows 20000 to 30000...Done. 2.525689125061035 total seconds elapsed
# importing rows 30000 to 40000...Done. 3.3281071186065674 total seconds elapsed
# importing rows 40000 to 50000...Done. 4.224911212921143 total seconds elapsed
# importing rows 50000 to 60000...Done. 5.09506630897522 total seconds elapsed
# importing rows 60000 to 70000...Done. 5.880917072296143 total seconds elapsed
# importing rows 70000 to 80000...Done. 6.722213983535767 total seconds elapsed
# importing rows 80000 to 90000...Done. 7.555500030517578 total seconds elapsed
# importing rows 90000 to 100000...Done. 8.39976716041565 total seconds elapsed
# importing rows 100000 to 110000...Done. 9.250158071517944 total seconds elapsed
# importing rows 110000 to 120000...Done. 10.086775064468384 total seconds elapsed
# ...
